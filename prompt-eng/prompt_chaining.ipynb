# %% [markdown]
# # Prompt Chaining

# %%
from _pipeline import create_payload, model_req

#### (1) User's High-Level Request
USER_REQUEST = """
Generate a high-level requirement analysis for a Discord chatbot that:
- Enables data scientists and business analysts to efficiently locate and extract relevant data from company databases to answer specific queries and generate reports.
"""

#### (2) First-Level: Initial High-Level Analysis
initial_prompt = f"""
You are an AI that specializes in software requirement analysis. Based on the following request, generate a high-level requirement analysis including functionality, user roles, and key features.

User Request:
{USER_REQUEST}
"""

# Send first request for high-level analysis
initial_payload = create_payload(
    target="ollama",
    model="llama3.2:latest",
    prompt=initial_prompt,
    temperature=1.0,
    num_ctx=300,
    num_predict=500,
)

initial_time, high_level_response = model_req(payload=initial_payload)
print("\n### High-Level Requirement Analysis ###\n", high_level_response)
if initial_time:
    print(f"High-Level Processing Time: {initial_time}s")

#### (3) Second-Level: Refinement with Technical Specifications
refinement_prompt = f"""
Based on the following high-level requirement analysis, refine it with:
- Technical architecture (APIs, Database Integration)
- Data security & privacy measures
- User authentication & role-based access
- AI & NLP capabilities for advanced query processing

High-Level Analysis:
{high_level_response}
"""

# Send second request for detailed refinement
refinement_payload = create_payload(
    target="ollama",
    model="llama3.2:latest",
    prompt=refinement_prompt,
    temperature=1.0,
    num_ctx=500,
    num_predict=500,
)

refinement_time, refined_response = model_req(payload=refinement_payload)
print("\n### Refined Technical Requirement Analysis ###\n", refined_response)
if refinement_time:
    print(f"Refinement Processing Time: {refinement_time}s")

#### (4) Third-Level (Optional): Validation & Finalization
validation_prompt = f"""
Review the following refined requirement analysis for a Discord chatbot. Validate its feasibility, highlight potential challenges, and suggest any improvements.

Refined Analysis:
{refined_response}
"""

# Send third request for validation and finalization
validation_payload = create_payload(
    target="ollama",
    model="llama3.2:latest",
    prompt=validation_prompt,
    temperature=1.0,
    num_ctx=500,
    num_predict=1000,
)

validation_time, final_response = model_req(payload=validation_payload)
print("\n### Final Validated Requirement Analysis ###\n", final_response)
if validation_time:
    print(f"Final Validation Processing Time: {validation_time}s")
# Out:
# {'model': 'llama3.2:latest', 'prompt': '\nYou are an AI that specializes in software requirement analysis. Based on the following request, generate a high-level requirement analysis including functionality, user roles, and key features.\n\nUser Request:\n\nGenerate a high-level requirement analysis for a Discord chatbot that:\n- Enables data scientists and business analysts to efficiently locate and extract relevant data from company databases to answer specific queries and generate reports.\n\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 300, 'num_predict': 500}}
#
# ### High-Level Requirement Analysis ###
#  **Discord Chatbot High-Level Requirement Analysis**
#
# **Functionality:**
#
# 1. **Data Retrieval**: The bot shall be able to connect to the company's database(s) and retrieve relevant data based on user queries.
# 2. **Query Processing**: The bot shall process user queries, identify the required data, and extract it from the database.
# 3. **Report Generation**: The bot shall generate reports based on the extracted data, including summary statistics, charts, and visualizations.
# 4. **Data Visualization**: The bot shall display the generated reports in a visually appealing format, suitable for Discord's chat environment (e.g., rich media, images).
# 5. **Query History**: The bot shall maintain a query history to track user queries and provide suggestions or auto-completion as users type.
#
# **User Roles:**
#
# 1. **Data Scientist**: A primary user role responsible for inputting queries, analyzing results, and interpreting data.
# 2. **Business Analyst**: Secondary user role who can view reports generated by the Data Scientist and make comments or ask questions.
# 3. **Moderators**: Support staff with basic permissions to manage query history, report issues, and provide general assistance.
#
# **Additional Features:**
#
# 1. **Data Storage**: A secure database to store user queries, data extracts, and reports.
# 2. **Real-time Collaboration**: Enable multiple users to collaborate on a single query, with features like simultaneous editing and commenting.
# 3. **Integrations**: Integrate with other tools (e.g., GitHub, Google Drive) for seamless data sharing and version control.
#
# **Technical Requirements:**
#
# 1. **Backend**: A robust backend framework (e.g., Flask, Django) to manage database interactions and API requests.
# 2. **Frontend**: A user-friendly interface built using a modern frontend framework (e.g., React, Angular).
# 3. **Database**: A suitable relational or NoSQL database management system for storing data extracts and reports.
#
# This design concept includes the following key components:
#
# 1.  Data Storage: Secure Database
# 2.  Real-time Collaboration: API Integration
# 3.  Backend Framework: Robust Backend
# 4.  Frontend Framework: Modern Frontend
# High-Level Processing Time: 15.061s
# {'model': 'llama3.2:latest', 'prompt': "\nBased on the following high-level requirement analysis, refine it with:\n- Technical architecture (APIs, Database Integration)\n- Data security & privacy measures\n- User authentication & role-based access\n- AI & NLP capabilities for advanced query processing\n\nHigh-Level Analysis:\n**Discord Chatbot High-Level Requirement Analysis**\n\n**Functionality:**\n\n1. **Data Retrieval**: The bot shall be able to connect to the company's database(s) and retrieve relevant data based on user queries.\n2. **Query Processing**: The bot shall process user queries, identify the required data, and extract it from the database.\n3. **Report Generation**: The bot shall generate reports based on the extracted data, including summary statistics, charts, and visualizations.\n4. **Data Visualization**: The bot shall display the generated reports in a visually appealing format, suitable for Discord's chat environment (e.g., rich media, images).\n5. **Query History**: The bot shall maintain a query history to track user queries and provide suggestions or auto-completion as users type.\n\n**User Roles:**\n\n1. **Data Scientist**: A primary user role responsible for inputting queries, analyzing results, and interpreting data.\n2. **Business Analyst**: Secondary user role who can view reports generated by the Data Scientist and make comments or ask questions.\n3. **Moderators**: Support staff with basic permissions to manage query history, report issues, and provide general assistance.\n\n**Additional Features:**\n\n1. **Data Storage**: A secure database to store user queries, data extracts, and reports.\n2. **Real-time Collaboration**: Enable multiple users to collaborate on a single query, with features like simultaneous editing and commenting.\n3. **Integrations**: Integrate with other tools (e.g., GitHub, Google Drive) for seamless data sharing and version control.\n\n**Technical Requirements:**\n\n1. **Backend**: A robust backend framework (e.g., Flask, Django) to manage database interactions and API requests.\n2. **Frontend**: A user-friendly interface built using a modern frontend framework (e.g., React, Angular).\n3. **Database**: A suitable relational or NoSQL database management system for storing data extracts and reports.\n\nThis design concept includes the following key components:\n\n1.  Data Storage: Secure Database\n2.  Real-time Collaboration: API Integration\n3.  Backend Framework: Robust Backend\n4.  Frontend Framework: Modern Frontend\n", 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 500, 'num_predict': 500}}
#
# ### Refined Technical Requirement Analysis ###
#  Here is a more detailed design specification based on your requirements:
#
# **System Overview**
#
# The system, named "QueryHub," will be a web-based collaborative tool for data scientists and analysts to work together on queries and share results. The system will provide features such as real-time collaboration, secure data storage, and integration with other tools.
#
# **Database Design**
#
# The database will be designed to store the following information:
#
# *   **Queries**: Store user queries, including input parameters and expected output.
# *   **Data Extracts**: Store extracted data from various sources, including files, APIs, and databases.
# *   **Reports**: Store generated reports, including summaries, visualizations, and results.
# *   **Collaboration History**: Store a history of all collaborative interactions, including user comments, edits, and version control.
#
# **Database Schema**
#
# The database schema will consist of the following tables:
#
# | Table Name | Columns |
# | --- | --- |
# | queries | id (primary key), title, description, input parameters, expected output |
# | data_extracts | id (primary key), query_id (foreign key), source, extracted_data |
# | reports | id (primary key), query_id (foreign key), title, summary, visualizations, results |
# | collaboration_history | id (primary key), query_id (foreign key), user_id (foreign key), action (create, edit, delete) |
#
# **Security**
#
# The system will implement the following security measures:
#
# *   **User Authentication**: Users will be authenticated using a username and password. Roles will be assigned to users based on their permissions.
# *   **Data Encryption**: Sensitive data will be encrypted both in transit and at rest.
# *   **Access Control**: Access to specific resources, such as reports and collaboration history, will be restricted based on user roles.
#
# **Collaboration Features**
#
# The system will provide the following collaboration features:
#
# *   **Real-time Collaboration**: Multiple users can edit a query simultaneously. Real-time updates will be reflected in all users' views.
# *   **Version Control**: A version control system will keep track of all changes made to a query or report.
# *   **Commenting and Tracking**: Users can leave comments on queries, reports, or data extracts, and track the history of these interactions.
#
# **Data Sources**
#
# The system will integrate with the following data sources:
#
# *   **Files**: Queries can be executed against files stored locally on the user's machine.
# *   **APIs**: Queries can be
# Refinement Processing Time: 14.519s
# {'model': 'llama3.2:latest', 'prompt': '\nReview the following refined requirement analysis for a Discord chatbot. Validate its feasibility, highlight potential challenges, and suggest any improvements.\n\nRefined Analysis:\nHere is a more detailed design specification based on your requirements:\n\n**System Overview**\n\nThe system, named "QueryHub," will be a web-based collaborative tool for data scientists and analysts to work together on queries and share results. The system will provide features such as real-time collaboration, secure data storage, and integration with other tools.\n\n**Database Design**\n\nThe database will be designed to store the following information:\n\n*   **Queries**: Store user queries, including input parameters and expected output.\n*   **Data Extracts**: Store extracted data from various sources, including files, APIs, and databases.\n*   **Reports**: Store generated reports, including summaries, visualizations, and results.\n*   **Collaboration History**: Store a history of all collaborative interactions, including user comments, edits, and version control.\n\n**Database Schema**\n\nThe database schema will consist of the following tables:\n\n| Table Name | Columns |\n| --- | --- |\n| queries | id (primary key), title, description, input parameters, expected output |\n| data_extracts | id (primary key), query_id (foreign key), source, extracted_data |\n| reports | id (primary key), query_id (foreign key), title, summary, visualizations, results |\n| collaboration_history | id (primary key), query_id (foreign key), user_id (foreign key), action (create, edit, delete) |\n\n**Security**\n\nThe system will implement the following security measures:\n\n*   **User Authentication**: Users will be authenticated using a username and password. Roles will be assigned to users based on their permissions.\n*   **Data Encryption**: Sensitive data will be encrypted both in transit and at rest.\n*   **Access Control**: Access to specific resources, such as reports and collaboration history, will be restricted based on user roles.\n\n**Collaboration Features**\n\nThe system will provide the following collaboration features:\n\n*   **Real-time Collaboration**: Multiple users can edit a query simultaneously. Real-time updates will be reflected in all users\' views.\n*   **Version Control**: A version control system will keep track of all changes made to a query or report.\n*   **Commenting and Tracking**: Users can leave comments on queries, reports, or data extracts, and track the history of these interactions.\n\n**Data Sources**\n\nThe system will integrate with the following data sources:\n\n*   **Files**: Queries can be executed against files stored locally on the user\'s machine.\n*   **APIs**: Queries can be\n', 'stream': False, 'options': {'temperature': 1.0, 'num_ctx': 500, 'num_predict': 1000}}
#
# ### Final Validated Requirement Analysis ###
#  **Query Execution Platform for Collaborative Data Analysis**
#
# ### Overview
#
# This platform is designed to facilitate collaborative data analysis among multiple users. It provides a secure, real-time environment where users can share and edit queries, track changes, and leave comments on each other's work.
#
# ### Security Measures
#
# #### User Authentication
#
# *   **Username and Password**: Users will be authenticated using a username and password.
# *   **Roles-Based Access Control**: Roles will be assigned to users based on their permissions, controlling access to specific resources within the platform.
#
# #### Data Encryption
#
# *   **Encryption in Transit**: Data transmitted between clients and servers will be encrypted using SSL/TLS.
# *   **Encryption at Rest**: Sensitive data stored on servers will be encrypted using a secure encryption algorithm (e.g., AES-256).
#
# #### Access Control
#
# *   **Query-Level Access Control**: Users will have restricted access to specific queries, preventing them from editing or deleting others' work without explicit permission.
#
# ### Collaboration Features
#
# #### Real-Time Collaboration
#
# *   **Simultaneous Editing**: Multiple users can edit a query simultaneously, with real-time updates reflected in all users' views.
# *   **Undo and Redo Functions**: Users will have the ability to undo and redo changes made during collaborative editing sessions.
#
# #### Commenting System
#
# *   **Comment Threads**: Users can leave comments on specific sections of queries, creating threaded comment discussions for easier reference and feedback exchange.
# *   **Comment Moderation**: Admin users can moderate comments, ensuring that all discussions remain constructive and relevant to the work being discussed.
#
# ### Query Management
#
# *   **Query Catalog**: A centralized catalog will allow users to browse, share, and download queries created by others.
# *   **Query Versioning**: Users will be able to track changes made to a query over time, with version history available for reference.
#
# ### User Interface
#
# *   **Clean, Intuitive Design**: The platform's interface will be designed with simplicity in mind, making it easy for users to navigate and use without needing extensive training.
# *   **User-Friendly Editing Tools**: A WYSIWYG editor will be used for text editing, while a graphing tool will enable users to visualize their queries.
#
# ### Server-Side Logic
#
# *   **Database Management**: The platform's database will store user information, query data, and activity logs.
# *   **Server-Side Scripting**: PHP or Python will be used as server-side languages to handle authentication, authorization, and other backend tasks.
#
# ### Security Measures
#
# *   **Data Encryption**: Queries will be stored in an encrypted format to ensure the security of user data.
# *   **Firewall Configuration**: A firewall will be configured to restrict access to unauthorized users.
#
# By following this comprehensive plan, you can create a robust, user-friendly platform that enables collaboration and productivity for your users.
# Final Validation Processing Time: 10.587s
